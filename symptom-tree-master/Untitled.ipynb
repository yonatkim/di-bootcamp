# %%
import pandas as pd
# Constants
DISEASE_SYMPTOMS = pd.read_csv('data\Diseases_Symptoms.csv', converters={"Symptoms": lambda x: x.split(", ")}).set_index('Code')
DISEASE_SYMPTOMS.columns = ['Disease', 'Symptoms', 'Treatment']

# %%
DISEASE_SYMPTOMS.head()
# Out:
#                           Disease  \
# Code
# 1                  Panic disorder
# 2                Vocal cord polyp
# 3                 Turner syndrome
# 4                  Cryptorchidism
# 5     Ethylene glycol poisoning-1
#
#                                                Symptoms  \
# Code
# 1     [Palpitations, Sweating, Trembling, Shortness ...
# 2            [Hoarseness, Vocal Changes, Vocal Fatigue]
# 3     [Short stature, Gonadal dysgenesis, Webbed nec...
# 4     [Absence or undescended testicle(s), empty scr...
# 5     [Nausea, vomiting, abdominal pain, General mal...
#
#                                               Treatment
# Code
# 1     Antidepressant medications, Cognitive Behavior...
# 2          Voice Rest, Speech Therapy, Surgical Removal
# 3     Growth hormone therapy, Estrogen replacement t...
# 4     Observation and monitoring (in cases of mild o...
# 5     Supportive Measures, Gastric Decontamination, ...

# %%
DISEASE_SYMPTOMS['Symptoms']
# Out:
# Code
# 1      [Palpitations, Sweating, Trembling, Shortness ...
# 2             [Hoarseness, Vocal Changes, Vocal Fatigue]
# 3      [Short stature, Gonadal dysgenesis, Webbed nec...
# 4      [Absence or undescended testicle(s), empty scr...
# 5      [Nausea, vomiting, abdominal pain, General mal...
#                              ...
# 396    [Severe abdominal or back pain, blood in urine...
# 397    [Fragile bones, loss of height over time, back...
# 398    [Joint pain, stiffness, swelling, fatigue, los...
# 399    [Frequent urination, Increased thirst, Weight ...
# 400    [Fatigue, Increased hunger, Slow healing of wo...
# Name: Symptoms, Length: 400, dtype: object

# %%
[s for symptom in DISEASE_SYMPTOMS['Symptoms'].values for s in symptom]
# Out:
# ['Palpitations',
#  'Sweating',
#  'Trembling',
#  'Shortness of breath',
#  'Fear of losing control',
#  'Dizziness',
#  'Hoarseness',
#  'Vocal Changes',
#  'Vocal Fatigue',
#  'Short stature',
#  'Gonadal dysgenesis',
#  'Webbed neck',
#  'Lymphedema',
#  'Absence or undescended testicle(s)',
#  'empty scrotum',
#  'smaller or underdeveloped testicle(s)',
#  'inguinal hernia',
#  'abnormal positioning of the testicle(s) (higher in the groin area)',
#  'Nausea',
#  'vomiting',
#  'abdominal pain',
#  'General malaise',
#  'weakness',
#  'Increased thirst',
#  'frequent urination',
#  'Metabolic acidosis',
#  'apid breathing',
#  'rapid heart rate',
#  'confusion',
#  'headache',
#  'dizziness',
#  'seizures',
#  'Decreased urine output',
#  'swelling in the legs and ankles',
#  'and signs of fluid overload',
#  'Severe kidney damage',
#  'Vaginal dryness',
#  'Vaginal burning',
#  'frequent urination',
#  'urinary tract infections',
#  'Painful intercourse',
#  'Pain',
#  'Swelling',
#  'Bruising',
#  'Deformity',
#  'Difficulty moving',
#  'Loss of function',
#  'Redness',
#  'Pain',
#  'tenderness',
#  'Swelling',
#  'Skin changes',
#  'Lymph node enlargement',
#  'Double vision',
#  'Eye fatigue',
#  'Poor depth perception',
#  'Head tilting',
#  'throbbing headache',
#  'Persistent hunger',
#  'Weight loss',
#  'Dehydration',
#  'Visible peristalsis',
#  'Palpable mass',
#  'Fussiness ',
#  'Lump',
#  'swelling',
#  'Facial numbness',
#  'tingling',
#  'Painless lump or swelling',
#  'Facial changes',
#  'Painless lump or swelling',
#  'Facial changes',
#  'Lump',
#  'swelling',
#  'Difficulty',
#  'pain when swallowing and speaking',
#  'Facial weakness',
#  'Facial paralysis ',
#  'Lump',
#  'swelling',
#  'Facial changes',
#  'Painless fluid-filled swelling in the oral cavity',
#  'Joint pain',
#  'stiffness',
#  'swelling',
#  'reduced range of motion',
#  'Swelling',
#  'pain',
#  'tenderness',
#  'difficulty eating',
#  'Swelling',
#  'pain',
#  'dry mouth',
#  'bad taste',
#  'Swelling',
#  'pain',
#  'dry mouth',
#  'bad taste',
#  'Frequent episodes of stone formation',
#  'Swelling',
#  'pain',
#  'dry mouth',
#  'bad taste',
#  'Swollen salivary glands (usually parotid)',
#  'fever',
#  'headache',
#  'fatigue',
#  'Severe swelling of the floor of the mouth',
#  'fever',
#  'difficulty swallowing',
#  'drooling',
#  'Painless swelling',
#  'usually on the lower lip or floor of the mouth',
#  'Swelling',
#  'pain',
#  'redness',
#  'fever',
#  'pus formation',
#  'Dry mouth and eyes',
#  'fatigue',
#  'joint pain',
#  'dry skin',
#  'Gradual loss of peripheral vision',
#  'tunnel vision',
#  'Severe eye pain',
#  'headache',
#  'blurred vision',
#  'halos around lights',
#  'nausea and vomiting',
#  'Gradual loss of vision',
#  'visual field defects',
#  'Cloudy or hazy eyes',
#  'excessive tearing',
#  'sensitivity to light',
#  'Varies depending on the underlying cause',
#  'Blurred vision',
#  'halos around lights',
#  'eye pain',
#  'Elevated intraocular pressure',
#  'visual field loss',
#  'Elevated intraocular pressure without optic nerve damage',
#  'Gradual loss of vision',
#  'visual field defects',
#  'Extreme weight loss',
#  'fear of gaining weight',
#  'distorted body image',
#  'Recurrent episodes of binge eating followed by purging behaviors',
#  'Recurrent episodes of binge eating without compensatory behaviors',
#  'Avoidance or restriction of certain foods or entire food groups',
#  'significant weight loss or failure to gain weight',
#  'Symptoms that do not meet the full criteria for a specific eating disorder',
#  'Obsessive focus on "clean" eating',
#  'healthy food choices',
#  'Persistent consumption of non-food substances',
#  'Repeated regurgitation and re-chewing of food',
#  'Sudden onset of neurological symptoms that resolve within 24 hours',
#  'Fever',
#  'chills',
#  'back or flank pain',
#  'frequent urination',
#  'Shoulder pain',
#  'weakness or loss of strength',
#  'limited range of motion',
#  'shoulder stiffness',
#  'Widespread musculoskeletal pain',
#  'fatigue',
#  'sleep disturbances',
#  'Extreme fatigue',
#  'cognitive difficulties',
#  'unrefreshing sleep',
#  'Severe and persistent pain',
#  'changes in skin color or temperature',
#  'swelling',
#  'stiffness',
#  'Localized muscle pain',
#  'trigger points',
#  'Recurrent',
#  'disabling migraines',
#  'Shooting or burning pain',
#  'tingling or numbness',
#  'High blood sugar levels during pregnancy',
#  'High blood pressure during pregnancy',
#  'High blood pressure without proteinuria (preeclampsia)',
#  'High blood pressure',
#  'proteinuria',
#  'swelling',
#  'headaches',
#  'visual disturbances',
#  'Severe nausea and vomiting during pregnancy',
#  'Painful urination',
#  'frequent urination',
#  'pelvic pain',
#  'cloudy urine',
#  'Fatigue',
#  'weakness',
#  'pale skin',
#  'shortness of breath',
#  'Lower back pain',
#  'discomfort in the pelvic area',
#  'Sharp or aching pain in the lower abdomen or groin',
#  'Vaginal bleeding',
#  'painless bleeding in the third trimester',
#  'Tingling',
#  'numbness',
#  'and pain in the hand and fingers',
#  'Sharp pain',
#  'tingling',
#  'or numbness that radiates from the lower back through the hips and down the leg',
#  'Enlarged',
#  'swollen veins',
#  'often in the legs',
#  'Swollen',
#  'itchy',
#  'or painful veins in the rectal area',
#  'Itchy skin',
#  'particularly on the hands and feet',
#  'Abdominal pain',
#  'jaundice (yellowing of the skin and eyes)',
#  'unexplained weight loss',
#  'loss of appetite',
#  'fatigue',
#  'nausea',
#  'vomiting',
#  'Difficulty breathing',
#  'rapid breathing',
#  'chest pain',
#  'Vaginal bleeding',
#  'abdominal pain or cramping',
#  'shoulder pain (if the fallopian tube ruptures)',
#  'Abdominal pain (often in the upper right quadrant)',
#  'jaundice',
#  'dark urine',
#  'pale stools',
#  'nausea',
#  'vomiting',
#  'endoscopic retrograde cholangiopancreatography (ERCP) with stone removal',
#  'sphincterotomy',
#  'Cholecystectomy ',
#  'Fatigue',
#  'jaundice',
#  'abdominal swelling (ascites)',
#  'easy bruising and bleeding',
#  'confusion',
#  'loss of appetite',
#  'weight loss',
#  'Chest or back pain',
#  'shortness of breath',
#  'hoarseness',
#  'difficulty swallowing',
#  'Headache',
#  'confusion',
#  'dizziness',
#  'nausea or vomiting',
#  'seizures',
#  'weakness or numbness',
#  'Developmental delays',
#  'intellectual disability',
#  'hearing loss',
#  'vision problems',
#  'heart defects',
#  'liver or spleen enlargement',
#  'rash at birth',
#  'Blurred or distorted vision',
#  'floaters',
#  'impaired color vision',
#  'dark or empty areas in the visual field',
#  'vision loss',
#  'Widespread musculoskeletal pain',
#  'fatigue',
#  'sleep disturbances',
#  'cognitive difficulties (fibro fog)',
#  'mood changes',
#  'Severe abdominal pain',
#  'bloody stools',
#  'diarrhea',
#  'nausea',
#  'vomiting',
#  'fever',
#  'rapid heart rate',
#  'low blood pressure',
#  'Growth deficiencies',
#  'facial abnormalities',
#  'developmental delays',
#  'intellectual disability',
#  'Severe abdominal pain',
#  'tenderness',
#  'bloating',
#  'fever',
#  'nausea',
#  'vomiting',
#  'loss of appetite',
#  'increased heart rate',
#  'Abdominal pain',
#  'tenderness',
#  'bruising',
#  'swelling',
#  'difficulty breathing',
#  'nausea',
#  'vomiting',
#  'changes in bowel movements',
#  'blood in urine or stool',
#  'Severe upper abdominal pain',
#  'nausea',
#  'vomiting',
#  'fever',
#  'rapid pulse',
#  'swollen and tender abdomen',
#  'jaundice',
#  'Redness',
#  'warmth',
#  'swelling',
#  'and tenderness along a vein',
#  'pain or discomfort',
#  'skin discoloration',
#  'visible veins',
#  'fever',
#  'Recurrent episodes of wheezing',
#  'shortness of breath',
#  'chest tightness',
#  'coughing',
#  'especially at night or in response to triggers such as allergens or exercise',
#  'Uncomfortable sensation in the legs',
#  'usually in the evening or at night',
#  'urge to move legs for relief',
#  'Shortness of breath',
#  'wheezing',
#  'chronic cough',
#  'chest tightness',
#  'fatigue',
#  'weight loss',
#  'Vaginal bleeding',
#  'cramping',
#  'abdominal pain',
#  'nausea',
#  'fatigue',
#  'emotional distress',
#  'Facial pain or pressure',
#  'nasal congestion',
#  'thick nasal discharge',
#  'post-nasal drip',
#  'cough',
#  'headache',
#  'fatigue',
#  'fever (in some cases)',
#  'Hemangioblastomas (tumors in the brain',
#  'spinal cord',
#  'or other organs)',
#  'retinal angiomas (abnormal blood vessel growth in the retina)',
#  'renal cell carcinomas (kidney tumors)',
#  'pheochromocytomas (adrenal gland tumors)',
#  'pancreatic cysts/tumors',
#  'other tumors or cysts',
#  'Cravings for alcohol',
#  'inability to control or limit alcohol consumption',
#  'withdrawal symptoms (such as tremors',
#  'anxiety',
#  'sweating) when attempting to stop or reduce alcohol use',
#  'continued use despite negative consequences (such as relationship problems',
#  'health issues)',
#  'neglecting responsibilities',
#  'tolerance to alcohol',
#  'Compulsive use of opioids',
#  'strong desire or cravings for opioids',
#  'inability to control or reduce opioid use',
#  'withdrawal symptoms (such as nausea',
#  'muscle aches',
#  'anxiety) when attempting to stop or reduce use',
#  'tolerance to opioids',
#  'continued use despite negative consequences (such as legal issues',
#  'health problems)',
#  'Increased energy and alertness',
#  'euphoria',
#  'decreased appetite',
#  'increased heart rate and blood pressure',
#  'insomnia',
#  'restlessness',
#  'irritability',
#  'paranoia',
#  'psychosis (in severe cases)',
#  'Increased appetite',
#  'relaxation',
#  'altered perception of time',
#  'impaired memory and concentration',
#  'bloodshot eyes',
#  'anxiety or paranoia (in some individuals)',
#  'withdrawal symptoms (such as irritability',
#  'insomnia) when attempting to stop or reduce cannabis use',
#  'continued use despite negative consequences (such as relationship problems',
#  'job difficulties)',
#  'Sedation',
#  'relaxation',
#  'reduced anxiety',
#  'drowsiness',
#  'poor coordination',
#  'memory impairment',
#  'withdrawal symptoms (such as rebound anxiety',
#  'insomnia',
#  'tremors) when attempting to stop or reduce benzodiazepine use',
#  'continued use despite negative consequences (such as relationship problems',
#  'health risks)',
#  'Altered perception of reality',
#  'visual or auditory hallucinations',
#  'changes in sensory experiences',
#  'introspective thoughts',
#  'feelings of connection or disconnection',
#  'anxiety or paranoia (in some individuals)',
#  'flashbacks (in some individuals)',
#  'Sedation',
#  'relaxation',
#  'reduced anxiety',
#  'drowsiness',
#  'poor coordination',
#  'memory impairment',
#  'withdrawal symptoms (such as rebound anxiety',
#  'insomnia',
#  'tremors) when attempting to stop or reduce use',
#  'continued use despite negative consequences (such as relationship problems',
#  'health risks)',
#  'Persistent feelings of sadness',
#  'emptiness',
#  'or hopelessness',
#  'frequent crying',
#  'irritability',
#  'loss of interest or pleasure in activities',
#  'difficulty bonding with the baby',
#  'changes in appetite or sleep patterns',
#  'overwhelming fatigue',
#  'feelings of guilt or worthlessness',
#  'trouble concentrating or making decisions',
#  'thoughts of self-harm or harming the baby',
#  'Chest pain or discomfort (angina)',
#  'shortness of breath',
#  'fatigue',
#  'irregular heartbeat',
#  'dizziness',
#  'nausea',
#  'sweating',
#  'jaw or arm pain (in some cases)',
#  'heart attack (when a coronary artery becomes completely blocked)',
#  'Chronic back pain and stiffness',
#  'especially in the morning or after periods of inactivity',
#  'limited range of motion in the spine',
#  'fatigue',
#  'inflammation and pain in other joints (such as hips',
#  'shoulders',
#  'knees)',
#  'discomfort or pain in the neck',
#  'difficulty maintaining proper posture',
#  'tenderness or swelling in affected areas',
#  'tingling or numbness in extremities in severe cases',
#  'Headaches',
#  'vision problems (such as blurred vision or loss of peripheral vision)',
#  'hormonal imbalances (such as excessive production or deficiency of specific hormones)',
#  'fatigue',
#  'weight gain or loss',
#  'menstrual irregularities',
#  'infertility',
#  'erectile dysfunction',
#  'growth abnormalities in children',
#  'mood changes',
#  'cognitive impairments',
#  'Heavy or prolonged menstrual periods',
#  'pelvic pain or pressure',
#  'frequent urination',
#  'difficulty emptying the bladder',
#  'constipation',
#  'backache',
#  'leg pain',
#  'enlarged abdomen or uterus',
#  'infertility or recurrent miscarriages (in some cases)',
#  'Abnormal vaginal bleeding outside of the menstrual period',
#  'unpredictable bleeding episodes',
#  'bleeding after sexual intercourse',
#  'bleeding after menopause',
#  'spotting or light bleeding between periods',
#  'prolonged or heavy bleeding',
#  'Painful',
#  'red lump or swelling on the eyelid',
#  'usually on the upper eyelid',
#  'sensitivity to light',
#  'blurred vision (if the chalazion affects the line of sight)',
#  'mild discomfort',
#  'tenderness',
#  'localized inflammation and swelling',
#  'Sudden and severe abdominal or pelvic pain on one side',
#  'sharp or stabbing pain',
#  'nausea',
#  'vomiting',
#  'fever',
#  'rapid heartbeat',
#  'abdominal tenderness',
#  'bloating',
#  'swelling',
#  'pain during intercourse',
#  'abnormal bleeding or spotting',
#  'Itching and irritation in the vagina and vulva',
#  'redness and swelling of the vulva',
#  'white',
#  'thick',
#  'clumpy vaginal discharge (resembling cottage cheese)',
#  'burning sensation during urination',
#  'pain during sexual intercourse',
#  'rash or soreness in the affected area',
#  'Ear pain (particularly behind the ear)',
#  'swelling and redness of the ear or the area behind the ear',
#  'fever',
#  'headache',
#  'hearing loss or impaired hearing',
#  'drainage of fluid or pus from the ear',
#  'earache',
#  'irritability (in infants and young children)',
#  'tenderness or pain when touching the area',
#  'mastoid bone protrusion or swelling',
#  'Chest pain (sharp or dull)',
#  'difficulty breathing or shortness of breath',
#  'rapid or shallow breathing',
#  'coughing up blood or pink-tinged sputum',
#  'decreased oxygen levels',
#  'wheezing',
#  'cyanosis (bluish discoloration of the skin)',
#  'chest wall bruising',
#  'rib fractures (associated injuries)',
#  'Shortness of breath',
#  'especially during physical activity or exertion',
#  'chest pain or discomfort',
#  'dizziness or lightheadedness',
#  'fainting or near-fainting episodes',
#  'heart palpitations (rapid or irregular heartbeat)',
#  'fatigue',
#  'swelling in the ankles',
#  'feet',
#  'or legs',
#  'Cough',
#  'shortness of breath',
#  'wheezing',
#  'chest pain',
#  'fever',
#  'night sweats',
#  'fatigue',
#  'weight loss',
#  'elevated eosinophil count in the blood or sputum',
#  'Blurred or hazy vision',
#  'eye pain or discomfort',
#  'redness or irritation of the eye',
#  'excessive tearing',
#  'sensitivity to light (photophobia)',
#  'foreign body sensation',
#  'dryness or excessive tearing',
#  'corneal abrasions or ulcers',
#  'distorted or irregular corneal shape',
#  'vision loss',
#  'Abdominal pain or discomfort',
#  'difficulty swallowing',
#  'choking or gagging',
#  'drooling',
#  'nausea or vomiting',
#  'loss of appetite',
#  'chest pain or pressure',
#  'respiratory distress',
#  'coughing or wheezing',
#  'gastrointestinal bleeding',
#  'bowel obstruction',
#  'perforation of the digestive tract',
#  'Eye pain',
#  'redness',
#  'swelling',
#  'blurred vision',
#  'decreased vision',
#  'floaters (dark spots or cobwebs in the vision)',
#  'increased sensitivity to light (photophobia)',
#  'discharge from the eye',
#  'excessive tearing',
#  'fever',
#  'Difficulty swallowing',
#  'Reduced hearing sensitivity',
#  'muffled or blocked sound',
#  'Visible bulge or swelling',
#  'discomfort or pain',
#  'Impaired memory and cognition',
#  'altered judgment',
#  'anxiety',
#  'Headache',
#  'fever',
#  'fatigue',
#  'cough',
#  'meningitis',
#  'pneumonia',
#  'Excessive body weight',
#  'increased risk of chronic conditions',
#  'Abdominal pain',
#  'bloating',
#  'heartburn',
#  'nausea',
#  'acidic taste',
#  'Joint pain',
#  'swelling',
#  'tenderness',
#  'limited range of motion',
#  'Difficulty swallowing',
#  'unintentional weight loss',
#  'chest pain',
#  'hoarseness',
#  'Shortness of breath',
#  'cough',
#  'wheezing',
#  'fatigue',
#  'chest discomfort or tightness',
#  'Joint pain',
#  'swelling',
#  'stiffness',
#  'limited range of motion',
#  'fever',
#  'rash',
#  'Rough',
#  'scaly patches on the skin',
#  'usually in sun-exposed areas',
#  'Ear pain',
#  'fever',
#  'fluid drainage from the ear',
#  'hearing loss or muffled hearing in the affected ear',
#  'Blurred or distorted vision',
#  'eye strain',
#  'headaches,uneven curvature of cornea',
#  'Benign tumors in various organs',
#  'seizures',
#  'developmental delays',
#  'skin abnormalities',
#  'Fever',
#  'chest pain',
#  'productive cough with foul-smelling or bloody sputum',
#  'Gradual hearing loss',
#  'difficulty hearing high-pitched sounds',
#  'speech sounds muffled or unclear',
#  'Yellowing of the skin and eyes',
#  'pale stools',
#  'dark urine',
#  'Severe pain',
#  'visible deformity',
#  'swelling',
#  'inability to move the elbow',
#  'numbness or tingling in the hand/arm',
#  'Neck or back pain',
#  'stiffness',
#  'limited range of motion',
#  'numbness or weakness in the extremities',
#  'Sore throat',
#  'fever',
#  'painful sores or blisters in the mouth and throat',
#  'difficulty swallowing',
#  'loss of appetite',
#  'Nausea',
#  'vomiting',
#  'drowsiness',
#  'dizziness',
#  'confusion',
#  'seizures',
#  'changes in heart rate',
#  'low blood pressure',
#  'respiratory distress',
#  'Redness',
#  'swelling',
#  'warmth',
#  'pain or tenderness at the wound site',
#  'pus or drainage from the wound',
#  'fever',
#  'malaise',
#  'Muscle wasting',
#  'fatigue',
#  'weakness',
#  'delayed wound healing',
#  'swelling of the limbs',
#  'hair loss',
#  'impaired immunity',
#  'Sudden',
#  'brief muscle contractions or jerks',
#  'often affecting the arms',
#  'legs',
#  'or face',
#  'Heel pain',
#  'especially when walking or standing',
#  'tenderness',
#  'swelling',
#  'inflammation of the surrounding tissue',
#  'Easy or excessive bruising',
#  'prolonged or excessive bleeding from cuts or injuries',
#  'frequent nosebleeds',
#  'heavy or prolonged menstrual periods',
#  'bleeding gums',
#  'blood in urine or stool',
#  'Fatigue',
#  'dizziness',
#  'fainting',
#  'chest pain or discomfort',
#  'shortness of breath',
#  'irregular heart rhythms',
#  'Most colonic polyps do not cause symptoms. Some larger polyps or certain types may cause rectal bleeding or changes in bowel habits',
#  'such as diarrhea or constipation.',
#  'Abnormal positioning of the urethral opening on the underside of the penis',
#  'penile curvature',
#  'spraying of urine',
#  'difficulty in urination',
#  'Muscle twitches or cramps',
#  'fatigue',
#  'weakness',
#  'loss of appetite',
#  'nausea',
#  'vomiting',
#  'irritability',
#  'mental confusion',
#  'irregular heartbeat',
#  'tingling or numbness',
#  'personality changes',
#  'seizures',
#  'Inability to conceive after one year of unprotected intercourse',
#  'irregular or absent menstrual cycles',
#  'hormonal imbalances',
#  'age-related factors',
#  'other',
#  'Chest pain (sharp and stabbing)',
#  'worsens with deep breaths or lying down',
#  'fever',
#  'Inattention',
#  'hyperactivity',
#  'impulsivity',
#  'Optic neuritis (vision loss',
#  'pain with eye movement)',
#  'transverse myelitis (weakness',
#  'numbness',
#  'or paralysis of the limbs',
#  'loss of bladder or bowel control)',
#  'Fatigue',
#  'shortness of breath',
#  'chest pain or discomfort',
#  'heart palpitations',
#  'fainting or lightheadedness',
#  'swollen legs or ankles',
#  'Chest pain',
#  'swelling and tenderness of the cartilage connecting the ribs to the breastbone',
#  'Depends on the specific cranial nerve involved; symptoms can include vision changes',
#  'eye movement abnormalities',
#  'facial weakness or paralysis',
#  'difficulty swallowing or speaking',
#  'loss of sensation in the face or other areas',
#  'Neurological symptoms that cannot be explained by a medical condition or injury',
#  'such as paralysis',
#  'blindness',
#  'seizures',
#  'or difficulty speaking',
#  'Severe and chronic pain',
#  'often in the limbs',
#  'with associated swelling',
#  'changes in skin color or temperature',
#  'abnormal sweating',
#  'limited range of motion',
#  'Hearing loss (gradual and progressive)',
#  'tinnitus (ringing in the ears)',
#  'dizziness or balance problems',
#  'Fatigue',
#  'weight gain',
#  'sensitivity to cold',
#  'dry skin',
#  'constipation',
#  'depression',
#  'muscle weakness',
#  'elevated cholesterol levels',
#  'Difficulty falling asleep or staying asleep',
#  'daytime sleepiness',
#  'irritability',
#  'difficulty concentrating',
#  'Itching and visible presence of lice or nits (eggs) in the hair',
#  'Fatigue',
#  'weakness',
#  'pale skin',
#  'shortness of breath',
#  'tingling or numbness in the hands and feet',
#  'balance problems',
#  'sore tongue',
#  'Persistent pain or discomfort in the vulva',
#  'burning',
#  'stinging',
#  'rawness',
#  'itching',
#  'Pelvic pain (during menstruation',
#  'intercourse',
#  'or bowel movements)',
#  'heavy menstrual bleeding',
#  'infertility',
#  'Inflammation of blood vessels leading to various symptoms depending on the affected organs',
#  'including rash',
#  'fever',
#  'fatigue',
#  'muscle and joint pain',
#  'shortness of breath',
#  'weight loss',
#  'Headache',
#  'dizziness',
#  'nausea or vomiting',
#  'confusion',
#  'memory problems',
#  'sensitivity to light or noise',
#  'mood changes',
#  'White patches or plaques in the mouth',
#  'often on the tongue or inside of the cheeks',
#  'that cannot be scraped off',
#  'Fatigue',
#  'swelling of the legs or ankles',
#  'decreased appetite',
#  'difficulty concentrating',
#  'increased urination or urine changes',
#  'blood in urine',
#  'high blood pressure',
#  'Frequent urination',
#  'urgency',
#  'pelvic pain',
#  'Eye pain',
#  'blurred vision',
#  'sensitivity to light',
#  'Persistent',
#  'painful erection',
#  'Muscle weakness',
#  'pain',
#  'inflammation',
#  'Fatigue',
#  'sore throat',
#  'swollen lymph nodes',
#  'Sharp',
#  'shooting pain along the affected nerve',
#  'Abdominal pain',
#  'high blood pressure',
#  'kidney cysts',
#  'Mood swings',
#  'manic episodes',
#  'depressive episodes',
#  'Fatigue',
#  'weight loss',
#  'organ dysfunction',
#  'Weakness',
#  'numbness',
#  'tingling in limbs',
#  'Heartburn',
#  'acid reflux',
#  'chest pain',
#  'Floaters in vision',
#  'blurry vision',
#  'eye pain',
#  'Nausea',
#  'vomiting',
#  'diarrhea',
#  'neurological symptoms',
#  'Thickening of the skin',
#  "Raynaud's phenomenon",
#  'Muscle weakness',
#  'fatigue',
#  'difficulty speaking',
#  'Shaking',
#  'dizziness',
#  'confusion',
#  'sweating',
#  'Lack of menstrual periods',
#  'Swelling',
#  'severe pain',
#  'inability to bear weight',
#  'Headache',
#  'dizziness',
#  'nausea',
#  'confusion',
#  'Chest pain',
#  'shortness of breath',
#  'palpitations',
#  'Heel pain',
#  'tenderness',
#  'difficulty walking',
#  'Difficulty seeing objects up close',
#  'blurred vision when focusing on near objects',
#  'Drowsiness',
#  'confusion',
#  'slowed breathing',
#  'Painful blisters on the skin and mucous membranes',
#  'Curvature of the penis',
#  'pain during erections',
#  'Heartburn',
#  'chest pain',
#  'difficulty swallowing',
#  'Muscle stiffness',
#  'tremors',
#  'involuntary movements',
#  'Vertigo',
#  'hearing loss',
#  'tinnitus',
#  'ear fullness',
#  'Pain during bowel movements',
#  'rectal bleeding',
#  'Ear pain',
#  'hearing loss',
#  'recurrent ear infections',
#  'Chronic constipation',
#  'abdominal distension',
#  'failure to pass meconium (in newborns)',
#  'Muscle pain and stiffness',
#  'joint pain',
#  'fatigue',
#  'Swelling in arms or legs',
#  'feeling of heaviness or tightness',
#  'Blood in urine',
#  'frequent urination',
#  'pelvic pain',
#  'Wheezing',
#  'shortness of breath',
#  'chest tightness',
#  'Severe eye pain',
#  'blurred vision',
#  'halos around lights',
#  'Knee pain',
#  'swelling',
#  'inability to straighten the leg',
#  'Pain radiating from the lower back to the leg',
#  'Fatigue',
#  'nausea',
#  'excessive thirst',
#  'kidney stones',
#  'Unintentional urine leakage during physical activity',
#  'Abdominal or flank pain',
#  'blood in urine',
#  'frequent urination',
#  'Swelling of the scrotum',
#  'Excessive hair growth in women',
#  'Flank pain',
#  'urinary frequency',
#  'swelling in the abdomen',
#  'Abdominal pain',
#  'bloating',
#  'changes in bowel movements',
#  'Surgical site pain',
#  'discomfort',
#  'swelling',
#  'Motor',
#  'cognitive',
#  'and psychiatric symptoms',
#  'Fever',
#  'headache',
#  'body aches',
#  'rash',
#  'Swollen lymph nodes',
#  'unexplained weight loss',
#  'fatigue',
#  'Redness',
#  'itching',
#  'rash',
#  'blistering',
#  'Fatigue',
#  'weakness',
#  'pale skin',
#  'Abdominal pain',
#  'bleeding',
#  'organ dysfunction',
#  'Eye redness',
#  'severe eye pain',
#  'blurred vision',
#  'Growth on the conjunctiva (white part of the eye)',
#  'Rash',
#  'itching',
#  'redness',
#  'peeling skin',
#  'Low blood sugar (hypoglycemia) symptoms (e.g.',
#  'confusion',
#  'sweating)',
#  'Excessively concentrated urine',
#  'low blood sodium levels',
#  'Mood swings',
#  'bloating',
#  'breast tenderness',
#  'irritability',
#  'Eye pain',
#  'swelling',
#  'redness',
#  'vision changes',
#  'Pain',
#  'swelling',
#  'bruising',
#  'difficulty walking',
#  'Confusion',
#  'forgetfulness',
#  'personality changes',
#  'tremors',
#  'Bone pain',
#  'fractures',
#  'fatigue',
#  'unexplained weight loss',
#  'Skin sores',
#  'fever',
#  'weight loss',
#  'enlarged spleen or liver',
#  'Fever',
#  'fatigue',
#  'body aches',
#  'heart and digestive problems',
#  'Muscle weakness',
#  'loss of sensation',
#  'chronic pain',
#  'Shortness of breath',
#  ...]

# %%
def diagnose(symptoms):
    '''diagnose the disease from the symptoms'''
    possible_diseases = []
    s = [s for symptom in DISEASE_SYMPTOMS['Symptoms'].values for s in symptom]
    for symptom in symptoms:
        if symptom in s:
            possible_diseases.extend(DISEASE_SYMPTOMS['Disease'])
    
    # Count occurrences of each disease
    disease_counts = {}
    for disease in possible_diseases:
        disease_counts[disease] = disease_counts.get(disease, 0) + 1
    
    # Sort diseases by frequency
    sorted_diseases = sorted(disease_counts.items(), key=lambda x: x[1], reverse=True)
    
    return sorted_diseases

# %%
def main():
    print("Welcome to the Disease Diagnosis System!")
    print("Please enter your symptoms (separated by commas):")
    symptoms_input = input().lower().split(',')
    symptoms = [symptom.strip() for symptom in symptoms_input]
    
    if len(symptoms) == 0:
        print("No symptoms provided.")
        return
    
    print("Diagnosis:")
    possible_diseases = diagnose(symptoms)
    
    if len(possible_diseases) == 0:
        print("No diseases found based on the provided symptoms.")
    else:
        for disease, count in possible_diseases:
            print(f"- {disease}: {count} symptom(s) matched")

# %%
print(DISEASE_SYMPTOMS['Symptoms'].head())
my_symptoms = ['Swelling', 'pain', 'dry mouth', 'bad taste']
[print(d) for d in diagnose(my_symptoms)]
main()
# Out:
# Code
# 1    [Palpitations, Sweating, Trembling, Shortness ...
# 2           [Hoarseness, Vocal Changes, Vocal Fatigue]
# 3    [Short stature, Gonadal dysgenesis, Webbed nec...
# 4    [Absence or undescended testicle(s), empty scr...
# 5    [Nausea, vomiting, abdominal pain, General mal...
# Name: Symptoms, dtype: object
# ('Sciatica', 12)
# ('Mucocele', 8)
# ('Fibromyalgia', 8)
# ('Complex Regional Pain Syndrome (CRPS)', 8)
# ('Urinary Tract Infection (UTI)', 8)
# ('Endometriosis', 8)
# ('Dermatitis due to Sun Exposure', 8)
# ('Panic disorder', 4)
# ('Vocal cord polyp', 4)
# ('Turner syndrome', 4)
# ('Cryptorchidism', 4)
# ('Ethylene glycol poisoning-1', 4)
# ('Ethylene glycol poisoning-2', 4)
# ('Ethylene glycol poisoning-3', 4)
# ('Atrophic vaginitis', 4)
# ('Fracture', 4)
# ('Cellulitis', 4)
# ('Eye alignment disorder', 4)
# ('Headache after lumbar puncture', 4)
# ('Pyloric stenosis', 4)
# ('Adenoid cystic carcinoma', 4)
# ('Pleomorphic adenoma', 4)
# ('Warthin tumor', 4)
# ('Mucoepidermoid carcinoma', 4)
# ('Acinic cell carcinoma', 4)
# ('Osteochondrosis', 4)
# ('Sialolithiasis', 4)
# ('Submandibular stones', 4)
# ('Parotid stones', 4)
# ('Recurrent salivary stones', 4)
# ("Wharton's duct stones", 4)
# ('Mumps', 4)
# ("Ludwig's angina", 4)
# ('Abscess', 4)
# ("Sjögren's syndrome", 4)
# ('Open-Angle Glaucoma', 4)
# ('Angle-Closure Glaucoma', 4)
# ('Normal-Tension Glaucoma', 4)
# ('Congenital Glaucoma', 4)
# ('Secondary Glaucoma', 4)
# ('Pigmentary Glaucoma', 4)
# ('Exfoliation Glaucoma', 4)
# ('Ocular Hypertension', 4)
# ('Low-Tension Glaucoma', 4)
# ('Anorexia Nervosa', 4)
# ('Bulimia Nervosa', 4)
# ('Binge Eating Disorder', 4)
# ('Avoidant/Restrictive Food Intake Disorder (ARFID)', 4)
# ('Other Specified Feeding or Eating Disorder (OSFED)', 4)
# ('Orthorexia Nervosa', 4)
# ('Pica', 4)
# ('Rumination Disorder', 4)
# ('Transient ischemic attack', 4)
# ('Pyelonephritis', 4)
# ('Rotator Cuff Injury', 4)
# ('Chronic Fatigue Syndrome', 4)
# ('Myofascial Pain Syndrome', 4)
# ('Chronic Migraine', 4)
# ('Neuropathic Pain', 4)
# ('Gestational Diabetes', 4)
# ('Pregnancy-Induced Hypertension', 4)
# ('Gestational Hypertension', 4)
# ('Preeclampsia', 4)
# ('Hyperemesis Gravidarum', 4)
# ('Anemia', 4)
# ('Pregnancy-Related Back Pain', 4)
# ('Round Ligament Pain', 4)
# ('Placenta Previa', 4)
# ('Carpal Tunnel Syndrome', 4)
# ('Varicose Veins', 4)
# ('Hemorrhoids', 4)
# ('Gestational Cholestasis', 4)
# ('Liver Cancer', 4)
# ('Atelectasis', 4)
# ('Ectopic Pregnancy', 4)
# ('Choledocholithiasis', 4)
# ('Cirrhosis', 4)
# ('Thoracic Aortic Aneurysm', 4)
# ('Subdural hemorrhage', 4)
# ('Congenital rubella', 4)
# ('Diabetic retinopathy', 4)
# ('Ischemia of the Bowel', 4)
# ('Fetal Alcohol Syndrome', 4)
# ('Peritonitis', 4)
# ('Abdominal Injury', 4)
# ('Acute Pancreatitis', 4)
# ('Thrombophlebitis', 4)
# ('Asthma', 4)
# ('Restless Leg Syndrome', 4)
# ('Emphysema', 4)
# ('Induced Abortion', 4)
# ('Acute Sinusitis', 4)
# ('Von Hippel-Lindau Disease', 4)
# ('Alcohol Use Disorder', 4)
# ('Opioid Use Disorder', 4)
# ('Stimulant Use Disorder', 4)
# ('Cannabis Use Disorder', 4)
# ('Benzodiazepine Use Disorder', 4)
# ('Hallucinogen Use Disorder', 4)
# ('Sedative, Hypnotic, or Anxiolytic Use Disorder', 4)
# ('Postpartum Depression', 4)
# ('Coronary Atherosclerosis', 4)
# ('Spondylitis', 4)
# ('Pituitary Adenoma', 4)
# ('Uterine Fibroids', 4)
# ('Idiopathic Nonmenstrual Bleeding', 4)
# ('Chalazion', 4)
# ('Ovarian Torsion', 4)
# ('Vaginal Yeast Infection', 4)
# ('Mastoiditis', 4)
# ('Lung Contusion', 4)
# ('Hypertrophic Obstructive Cardiomyopathy (HOCM)', 4)
# ('Pulmonary Eosinophilia', 4)
# ('Corneal Disorder', 4)
# ('Foreign Body in the Gastrointestinal Tract', 4)
# ('Endophthalmitis', 4)
# ('Achalasia', 4)
# ('Conductive Hearing Loss', 4)
# ('Abdominal Hernia', 4)
# ('Marijuana Abuse', 4)
# ('Cryptococcosis', 4)
# ('Obesity', 4)
# ('Indigestion', 4)
# ('Bursitis', 4)
# ('Esophageal Cancer', 4)
# ('Pulmonary Congestion', 4)
# ('Juvenile Rheumatoid Arthritis', 4)
# ('Actinic Keratosis', 4)
# ('Acute Otitis Media', 4)
# ('Astigmatism', 4)
# ('Tuberous Sclerosis', 4)
# ('Empyema', 4)
# ('Presbycusis', 4)
# ('Neonatal Jaundice', 4)
# ('Dislocation of the Elbow', 4)
# ('Spondylosis', 4)
# ('Herpangina', 4)
# ('Poisoning due to Antidepressants', 4)
# ('Infection of Open Wound', 4)
# ('Protein Deficiency', 4)
# ('Myoclonus', 4)
# ('Bone Spur of the Calcaneus', 4)
# ('Von Willebrand Disease', 4)
# ('Heart Block', 4)
# ('Colonic Polyp', 4)
# ('Hypospadias', 4)
# ('Magnesium Deficiency', 4)
# ('Female Infertility of Unknown Cause', 4)
# ('Pericarditis', 4)
# ('Attention Deficit Hyperactivity Disorder (ADHD)', 4)
# ('Neuromyelitis Optica', 4)
# ('Pulmonic Valve Disease', 4)
# ('Tietze Syndrome', 4)
# ('Cranial Nerve Palsy', 4)
# ('Conversion Disorder', 4)
# ('Complex Regional Pain Syndrome', 4)
# ('Otosclerosis', 4)
# ('Hypothyroidism', 4)
# ('Primary Insomnia', 4)
# ('Lice', 4)
# ('Vitamin B12 Deficiency', 4)
# ('Vulvodynia', 4)
# ('Vasculitis', 4)
# ('Concussion', 4)
# ('Oral Leukoplakia', 4)
# ('Chronic Kidney Disease', 4)
# ('Bladder Disorder', 4)
# ('Chorioretinitis', 4)
# ('Priapism', 4)
# ('Myositis', 4)
# ('Mononucleosis', 4)
# ('Neuralgia', 4)
# ('Polycystic Kidney Disease', 4)
# ('Bipolar Disorder', 4)
# ('Amyloidosis', 4)
# ('Chronic Inflammatory Demyelinating Polyneuropathy (CIDP)', 4)
# ('Gastroesophageal Reflux Disease (GERD)', 4)
# ('Vitreous Hemorrhage', 4)
# ('Antimicrobial Drugs Poisoning', 4)
# ('Scleroderma', 4)
# ('Myasthenia Gravis', 4)
# ('Hypoglycemia', 4)
# ('Idiopathic Absence of Menstruation', 4)
# ('Dislocation of the Ankle', 4)
# ('Carbon Monoxide Poisoning', 4)
# ('Panic Attack', 4)
# ('Plantar Fasciitis', 4)
# ('Hyperopia', 4)
# ('Sedatives Poisoning', 4)
# ('Pemphigus', 4)
# ('Peyronie Disease', 4)
# ('Hiatal Hernia', 4)
# ('Extrapyramidal Effect of Drugs', 4)
# ('Meniere Disease', 4)
# ('Anal Fissure', 4)
# ('Chronic Otitis Media', 4)
# ('Hirschsprung Disease', 4)
# ('Polymyalgia Rheumatica', 4)
# ('Lymphedema', 4)
# ('Bladder Cancer', 4)
# ('Acute Bronchospasm', 4)
# ('Acute Glaucoma', 4)
# ('Dislocation of the Patella', 4)
# ('Hypercalcemia', 4)
# ('Stress Incontinence', 4)
# ('Benign Kidney Cyst', 4)
# ('Hydrocele of the Testicle', 4)
# ('Hirsutism', 4)
# ('Hydronephrosis', 4)
# ('Diverticulosis', 4)
# ('Pain after an Operation', 4)
# ('Huntington Disease', 4)
# ('West Nile Virus', 4)
# ('Lymphoma', 4)
# ('Anemia due to Chronic Kidney Disease', 4)
# ('Injury to Internal Organ', 4)
# ('Scleritis', 4)
# ('Pterygium', 4)
# ('Fungal Infection of the Skin', 4)
# ('Insulin Overdose', 4)
# ('Syndrome of Inappropriate Secretion of ADH (SIADH)', 4)
# ('Premenstrual Tension Syndrome', 4)
# ('Orbital Cellulitis', 4)
# ('Injury to the Leg', 4)
# ('Hepatic Encephalopathy', 4)
# ('Bone Cancer', 4)
# ('Leishmaniasis', 4)
# ('Chagas Disease', 4)
# ('Syringomyelia', 4)
# ('Pulmonary Fibrosis', 4)
# ('Mitral Valve Disease', 4)
# ('Parkinson Disease', 4)
# ('Gout', 4)
# ('Otitis Media', 4)
# ('Myelodysplastic Syndrome', 4)
# ('Fracture of the Shoulder', 4)
# ('Acute Kidney Injury', 4)
# ('Threatened Pregnancy', 4)
# ('Intracranial Abscess', 4)
# ('Gum Disease', 4)
# ('Open Wound from Surgical Incision', 4)
# ('Gastrointestinal Hemorrhage', 4)
# ('Seborrheic Dermatitis', 4)
# ('Drug Abuse (Methamphetamine)', 4)
# ('Torticollis', 4)
# ('Antihypertensives Poisoning', 4)
# ('Tension Headache', 4)
# ('Alcohol Intoxication', 4)
# ('Scurvy', 4)
# ('Narcolepsy', 4)
# ('Food Allergy', 4)
# ('Labyrinthitis', 4)
# ('Anxiety', 4)
# ('Impulse Control Disorder', 4)
# ('Stenosis of the Tear Duct', 4)
# ('Abscess of Nose', 4)
# ('Omphalitis', 4)
# ('Leukemia', 4)
# ('Bell Palsy', 4)
# ('Conjunctivitis due to Allergy', 4)
# ('Drug Reaction', 4)
# ('Adrenal Cancer', 4)
# ('Myopia', 4)
# ('Osteoarthritis', 4)
# ('Thyroid Disease', 4)
# ('Pharyngitis', 4)
# ('Chronic Rheumatic Fever', 4)
# ('Hypocalcemia', 4)
# ('Macular Degeneration', 4)
# ('Pneumonia', 4)
# ('Cold Sore', 4)
# ('Premature Ventricular Contractions (PVCs)', 4)
# ('Chancroid', 4)
# ('Testicular Cancer', 4)
# ('Hydrocephalus', 4)
# ('Breast Cancer', 4)
# ('Anemia due to Malignancy', 4)
# ('Esophageal Varices', 4)
# ('Endometrial Cancer', 4)
# ('Cystic Fibrosis', 4)
# ('Intertrigo', 4)
# ('Parathyroid Adenoma', 4)
# ('Glucocorticoid Deficiency', 4)
# ('Temporomandibular Joint Disorder', 4)
# ('Wilson Disease', 4)
# ('Vesicoureteral Reflux', 4)
# ('Vitamin A Deficiency', 4)
# ('Gonorrhea', 4)
# ('Fracture of the Rib', 4)
# ('Ependymoma', 4)
# ('Hepatitis due to a Toxin', 4)
# ('Vaginal Cyst', 4)
# ('Chronic Knee Pain', 4)
# ('Pinguecula', 4)
# ('Hypergammaglobulinemia', 4)
# ('Pituitary Disorder', 4)
# ('Kidney Stone', 4)
# ('Autism', 4)
# ('Cat Scratch Disease', 4)
# ('Chronic Glaucoma', 4)
# ('Retinal Detachment', 4)
# ('Aplastic Anemia', 4)
# ('Overflow Incontinence', 4)
# ('Rabies', 4)
# ('Hemolytic Anemia', 4)
# ('Lateral Epicondylitis (Tennis Elbow)', 4)
# ('Syphilis', 4)
# ('Diabetic Kidney Disease', 4)
# ('Nose Disorder', 4)
# ('Drug Withdrawal', 4)
# ('Dental Caries', 4)
# ('Hypercholesterolemia', 4)
# ('Fracture of the Patella', 4)
# ('Kidney Failure', 4)
# ('Fracture of the Neck', 4)
# ('Muscle Spasm', 4)
# ('Hemophilia', 4)
# ('Hyperosmotic Hyperketotic State', 4)
# ('Peritonsillar Abscess', 4)
# ('Gastroparesis', 4)
# ('Fat Embolism', 4)
# ('Polycythemia Vera', 4)
# ('Thrombocytopenia', 4)
# ('Head and Neck Cancer', 4)
# ('Pseudohypoparathyroidism', 4)
# ('Goiter', 4)
# ('Urge Incontinence', 4)
# ('Edward Syndrome', 4)
# ('Muscular Dystrophy', 4)
# ('Mittelschmerz', 4)
# ('Corneal Abrasion', 4)
# ('Anemia of Chronic Disease', 4)
# ('Dysthymic Disorder', 4)
# ('Scarlet Fever', 4)
# ('Hypertensive Heart Disease', 4)
# ('Drug Abuse (Barbiturates)', 4)
# ('Polycystic Ovarian Syndrome', 4)
# ('Encephalitis', 4)
# ('Cyst of the Eyelid', 4)
# ('Balanitis', 4)
# ('Foreign Body in the Throat', 4)
# ('Drug Abuse (Cocaine)', 4)
# ('Optic Neuritis', 4)
# ('Intestinal Malabsorption', 4)
# ('Lead Poisoning', 4)
# ('Viral Warts', 4)
# ('Hyperhidrosis', 4)
# ('Stroke', 4)
# ('Pilonidal Cyst', 4)
# ('Crushing Injury', 4)
# ('Normal Pressure Hydrocephalus', 4)
# ('Alopecia', 4)
# ('Hashimoto Thyroiditis', 4)
# ('Flat Feet', 4)
# ('Nonalcoholic Liver Disease (NASH)', 4)
# ('Hemarthrosis', 4)
# ('Pelvic Organ Prolapse', 4)
# ('Fracture of the Arm', 4)
# ('Coagulation (Bleeding) Disorder', 4)
# ('Intracranial Hemorrhage', 4)
# ('Hyperkalemia', 4)
# ('Cornea Infection', 4)
# ('Abscess of the Lung', 4)
# ('Dengue Fever', 4)
# ('Chronic Sinusitis', 4)
# ('Cholesteatoma', 4)
# ('Volvulus', 4)
# ('Injury to the Finger', 4)
# ('Poisoning due to Analgesics', 4)
# ('Atrial Fibrillation', 4)
# ('Pinworm Infection', 4)
# ('Urethral Valves', 4)
# ('Migraine', 4)
# ('Arthritis', 4)
# ('Lupus', 4)
# ('Chronic Headache', 4)
# ('Dry Skin', 4)
# ('Eczema', 4)
# ('Psoriasis', 4)
# ('Scabies', 4)
# ('Urticaria (Hives)', 4)
# ('Insect Bites', 4)
# ('Contact Dermatitis', 4)
# ('Parasitic Infections', 4)
# ('Influenza (Flu)', 4)
# ('Bronchitis', 4)
# ('Gastroenteritis (Stomach Flu)', 4)
# ('Urinary Stones (Kidney Stones)', 4)
# ('Osteoporosis', 4)
# ('Rheumatoid Arthritis', 4)
# ('Type 1 Diabetes', 4)
# ('Type 2 Diabetes', 4)
# Welcome to the Disease Diagnosis System!
# Please enter your symptoms (separated by commas):
# Palpitations, Sweating, Trembling, Shortness of breath, Fear of losing control, Dizziness
# Diagnosis:
# - Sciatica: 12 symptom(s) matched
# - Mucocele: 8 symptom(s) matched
# - Fibromyalgia: 8 symptom(s) matched
# - Complex Regional Pain Syndrome (CRPS): 8 symptom(s) matched
# - Urinary Tract Infection (UTI): 8 symptom(s) matched
# - Endometriosis: 8 symptom(s) matched
# - Dermatitis due to Sun Exposure: 8 symptom(s) matched
# - Panic disorder: 4 symptom(s) matched
# - Vocal cord polyp: 4 symptom(s) matched
# - Turner syndrome: 4 symptom(s) matched
# - Cryptorchidism: 4 symptom(s) matched
# - Ethylene glycol poisoning-1: 4 symptom(s) matched
# - Ethylene glycol poisoning-2: 4 symptom(s) matched
# - Ethylene glycol poisoning-3: 4 symptom(s) matched
# - Atrophic vaginitis: 4 symptom(s) matched
# - Fracture: 4 symptom(s) matched
# - Cellulitis: 4 symptom(s) matched
# - Eye alignment disorder: 4 symptom(s) matched
# - Headache after lumbar puncture: 4 symptom(s) matched
# - Pyloric stenosis: 4 symptom(s) matched
# - Adenoid cystic carcinoma: 4 symptom(s) matched
# - Pleomorphic adenoma: 4 symptom(s) matched
# - Warthin tumor: 4 symptom(s) matched
# - Mucoepidermoid carcinoma: 4 symptom(s) matched
# - Cyst of the Eyelid: 4 symptom(s) matched
# - Balanitis: 4 symptom(s) matched
# - Foreign Body in the Throat: 4 symptom(s) matched
# - Drug Abuse (Cocaine): 4 symptom(s) matched
# - Optic Neuritis: 4 symptom(s) matched
# - Intestinal Malabsorption: 4 symptom(s) matched
# - Lead Poisoning: 4 symptom(s) matched
# - Viral Warts: 4 symptom(s) matched
# - Hyperhidrosis: 4 symptom(s) matched
# - Stroke: 4 symptom(s) matched
# - Pilonidal Cyst: 4 symptom(s) matched
# - Crushing Injury: 4 symptom(s) matched
# - Normal Pressure Hydrocephalus: 4 symptom(s) matched
# - Alopecia: 4 symptom(s) matched
# - Hashimoto Thyroiditis: 4 symptom(s) matched
# - Flat Feet: 4 symptom(s) matched
# - Nonalcoholic Liver Disease (NASH): 4 symptom(s) matched
# - Hemarthrosis: 4 symptom(s) matched
# - Pelvic Organ Prolapse: 4 symptom(s) matched
# - Fracture of the Arm: 4 symptom(s) matched
# - Coagulation (Bleeding) Disorder: 4 symptom(s) matched
# - Intracranial Hemorrhage: 4 symptom(s) matched
# - Hyperkalemia: 4 symptom(s) matched
# - Cornea Infection: 4 symptom(s) matched
# - Abscess of the Lung: 4 symptom(s) matched
# - Dengue Fever: 4 symptom(s) matched
# - Chronic Sinusitis: 4 symptom(s) matched
# - Cholesteatoma: 4 symptom(s) matched
# - Volvulus: 4 symptom(s) matched
# - Injury to the Finger: 4 symptom(s) matched
# - Poisoning due to Analgesics: 4 symptom(s) matched
# - Atrial Fibrillation: 4 symptom(s) matched
# - Pinworm Infection: 4 symptom(s) matched
# - Urethral Valves: 4 symptom(s) matched
# - Migraine: 4 symptom(s) matched
# - Arthritis: 4 symptom(s) matched
# - Lupus: 4 symptom(s) matched
# - Chronic Headache: 4 symptom(s) matched
# - Dry Skin: 4 symptom(s) matched
# - Eczema: 4 symptom(s) matched
# - Psoriasis: 4 symptom(s) matched
# - Scabies: 4 symptom(s) matched
# - Urticaria (Hives): 4 symptom(s) matched
# - Insect Bites: 4 symptom(s) matched
# - Contact Dermatitis: 4 symptom(s) matched
# - Parasitic Infections: 4 symptom(s) matched
# - Influenza (Flu): 4 symptom(s) matched
# - Bronchitis: 4 symptom(s) matched
# - Gastroenteritis (Stomach Flu): 4 symptom(s) matched
# - Urinary Stones (Kidney Stones): 4 symptom(s) matched
# - Osteoporosis: 4 symptom(s) matched
# - Rheumatoid Arthritis: 4 symptom(s) matched
# - Type 1 Diabetes: 4 symptom(s) matched
# - Type 2 Diabetes: 4 symptom(s) matched

# %%
from collections import Counter

# %%
word1 = 'MEAT'
word2 = 'MATE'
word_list = ['TEAM', 'MATE', 'TAME']

# %%
def is_anagram(w1, w2):
    return Counter(filter(str.isalnum, word1)) == Counter(filter(str.isalnum, word2))

# %%
 anagrams = []
def get_anagrams(word, word_list):
        '''Returns all matches found'''
        for w in word_list:
            if is_anagram(w, word):
                anagrams.append(w)

# %%
get_anagrams(word1, word_list)

# %%
anagrams
# Out:
# ['TEAM', 'MATE', 'TAME']
